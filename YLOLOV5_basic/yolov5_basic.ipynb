# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Step 1 : Clone yolov5 repository

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 2486, done.
# remote: Total 2486 (delta 0), reused 0 (delta 0), pack-reused 2486
# Receiving objects: 100% (2486/2486), 5.32 MiB | 7.29 MiB/s, done.
# Resolving deltas: 100% (1634/1634), done.

# %% [markdown]
# Step 2: Change Directory to yolov5

# %%
# %cd yolov5/
# Out:
# /content/yolov5

# %% [markdown]
# Step 3: Install Dependencies

# %%
# !pip install -U -r requirements.txt
# Out:
# Requirement already up-to-date: Cython in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 4)) (0.29.21)
# ...
#      |████████████████████████████████| 11.6MB 8.6MB/s
# ...
#      |████████████████████████████████| 14.5MB 235kB/s
# ...
#      |████████████████████████████████| 49.4MB 57kB/s
# ...
#      |████████████████████████████████| 2.2MB 50.9MB/s
# ...
#      |████████████████████████████████| 276kB 58.4MB/s
# ...
#      |████████████████████████████████| 25.9MB 119kB/s
# Requirement already up-to-date: tensorboard>=2.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 11)) (2.3.0)
# Requirement already up-to-date: torch>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 12)) (1.6.0+cu101)
# Requirement already up-to-date: torchvision>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 13)) (0.7.0+cu101)
# ...
#      |████████████████████████████████| 71kB 10.2MB/s
# ...

# %% [markdown]
# Step 4: Run Object Detection on Images. Provide image path. Upload image in the inference/images/ folder

# %%
# !python detect.py --source ./inference/images/public.jpg --weights yolov5s.pt --conf 0.4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=640, iou_thres=0.5, output='inference/output', save_txt=False, source='./inference/images/public.jpg', update=False, view_img=False, weights=['yolov5s.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Fusing layers...
# Model Summary: 140 layers, 7.45958e+06 parameters, 6.61683e+06 gradients
# image 1/1 /content/yolov5/inference/images/public.jpg: 448x640 25 persons, 6 chairs, Done. (0.013s)
# Results saved to inference/output
# Done. (0.099s)

# %% [markdown]
# Step 5: Display image in colab

# %%
img = cv.imread("/content/yolov5/inference/output/public.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1500x950 at 0x7FBB9AE04518>

# %%
# !python detect.py --source inference/videos/vid.mp4 --weights yolov5s.pt --conf 0.4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=640, iou_thres=0.5, output='inference/output', save_txt=False, source='inference/videos/vid.mp4', update=False, view_img=False, weights=['yolov5s.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Fusing layers...
# Model Summary: 140 layers, 7.45958e+06 parameters, 6.61683e+06 gradients
# video 1/1 (1/1020) /content/yolov5/inference/videos/vid.mp4: 384x640 10 persons, 1 motorcycles, 5 horses, Done. (0.013s)
# video 1/1 (2/1020) /content/yolov5/inference/videos/vid.mp4: 384x640 9 persons, 1 motorcycles, 6 horses, Done. (0.011s)
# video 1/1 (3/1020) /content/yolov5/inference/videos/vid.mp4: 384x640 9 persons, 1 motorcycles, 3 horses, Done. (0.011s)
# video 1/1 (4/1020) /content/yolov5/inference/videos/vid.mp4: 384x640 9 persons, 1 motorcycles, 3 horses, Done. (0.019s)
# ...
